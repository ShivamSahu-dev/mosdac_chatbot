# %%
import pandas as pd
from mosdac_utils import make_all_products_dataframe

# %%
df = pd.read_csv(r"C:\Users\WELCOME\Desktop\mosdac\raw_data\satellites_sensors_data.csv")

# %%
final_df = make_all_products_dataframe(satelite_sensors_df=df)
# Out:
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# Status Code: 200
# Data received.
# Sending request...
# ...

# %%
final_df.shape
# Out:
# (288, 18)

# %%
final_df.head()
# Out:
#   satellite_name  satellite_id sensor_name  sensor_id      prefix  \
# 0         EOS-06            22         OCM         16     E06OCML
# 1         EOS-06            22         OCM         16     E06OCML
# 2         EOS-06            22         OCM         16  E06OCML2OC
# 3         EOS-06            22         OCM         16     E06OCML
# 4         EOS-06            22         OCM         16     E06OCML
#
#                                               suffix   id               name  \
# 0                                               .jpg  421  E06OCM_L2C_LAC_AD
# 1                                               .jpg  423  E06OCM_L2C_LAC_GA
# 2  *LAC_cdm_v1.0.0.jpg,*LAC_chl_v1.0.0.jpg,*LAC_b...  425  E06OCM_L2C_LAC_OC
# 3                                               .jpg  424  E06OCM_L2C_LAC_PR
# 4                                               .jpg  429  E06OCM_L2C_LAC_PS
#
#                                          description   startdate     enddate  \
# ...

# %%
final_df.to_csv(r"C:\Users\WELCOME\Desktop\mosdac\raw_data\satellite_all_products_data.csv", index=False)
